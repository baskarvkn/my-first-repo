# %% [markdown]
# <a href="https://colab.research.google.com/github/baskarvkn/my-first-repo/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt

x= 50, 70, 60,90, 150,60
y= 50,100,150, 200, 250, 300

#plt.plot(x,y,'-')
plt.hist(x,y)

plt.title("Number Graph")
plt.show()
print(x)
